# %% [markdown]
# # Seaborn

# %% [markdown]
# Referências:
# * Site Seaborn https://seaborn.pydata.org/
# * Galeria de Exemplos https://seaborn.pydata.org/examples/index.html
#
# * https://www.youtube.com/watch?v=6GUZXDef2U0

# %% [markdown]
# ## Setup

# %% [markdown]
# `conda install seaborn`

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Tema

# %% [markdown]
# * https://seaborn.pydata.org/generated/seaborn.set_theme.html?highlight=set_theme
# * http://seaborn.pydata.org/tutorial/aesthetics.html

# %%
sns.set_theme(style="darkgrid")

# %% [markdown]
# ## Import Data

# %%
list(sns.get_dataset_names())
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df_tips = sns.load_dataset("tips")
df_tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_rand = pd.DataFrame(dict(time=np.random.choice(list(range(50)), 50), value=np.random.randn(50).cumsum()))
df_rand.head(4)
# Out:
#    time     value
# 0     7 -0.498014
# 1    43  0.448311
# 2    10 -0.186444
# 3     0  1.150917

# %%
df_fmri = sns.load_dataset("fmri")
df_fmri.head(4)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134

# %%
df_penguins = sns.load_dataset("penguins")
df_penguins.head(4)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN

# %%
df_titanic = sns.load_dataset("titanic")
df_titanic.head(4)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
df_crash = sns.load_dataset("car_crashes")
corr_crash = df_crash.corr()

# %% [markdown]
# ## Gráfico Dispersão (scatter plot)

# %% [markdown]
# * https://seaborn.pydata.org/tutorial/relational.html

# %%
sns.relplot(x="total_bill", y="tip", data=df_tips);

# %% [markdown]
# #### hue

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=df_tips);

# %% [markdown]
# #### Style

# %%
sns.relplot(x="total_bill", y="tip", style="smoker", data=df_tips);

# %% [markdown]
# #### Hue & Style

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=df_tips);

# %% [markdown]
# #### Palette

# %%
sns.relplot(x="total_bill", y="tip", hue="size", palette="ch:r=-.5,l=.75", data=df_tips);

# %% [markdown]
# #### Size

# %%
sns.relplot(x="total_bill", y="tip", size="size", data=df_tips);

# %%
sns.relplot(x="total_bill", y="tip", size="size", sizes=(15, 200), data=df_tips);

# %% [markdown]
# ## Gráfico de linha

# %% [markdown]
# * https://seaborn.pydata.org/tutorial/relational.html

# %%
sns.relplot(x="time", y="value", kind="line", data=df_rand);

# %%
sns.lineplot(x="time", y="value", data=df_rand);

# %% [markdown]
# #### Sort

# %%
sns.relplot(x="time", y="value", sort=False, kind="line", data=df_rand);

# %% [markdown]
# #### Tendência - ci

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=df_fmri, ci=None);

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=df_fmri);

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=df_fmri, ci='sd');

# %% [markdown]
# #### Estimator

# %%
sns.relplot(x="timepoint", y="signal", estimator=None, kind="line", data=df_fmri);

# %% [markdown]
# #### Hue

# %%
sns.relplot(x="timepoint", y="signal", hue="event", kind="line", data=df_fmri);

# %% [markdown]
# #### Style

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event", kind="line", data=df_fmri);

# %% [markdown]
# #### Markers

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event", dashes=False, markers=True, kind="line", data=df_fmri);

# %% [markdown]
# #### Hue & Style & ci & Markers

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event", kind="line", data=df_fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event", kind="line", ci=None, markers=True, data=df_fmri);

# %% [markdown]
# #### Units

# %%
sns.relplot(x="timepoint", y="signal", hue="region", units="subject", estimator=None, kind="line", data=df_fmri[df_fmri["event"].isin(['stim'])] );

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event", estimator=None, kind="line", data=df_fmri[df_fmri["event"].isin(['stim', 'cue'])] );

# %% [markdown]
# ## Multiplos Gráficos

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", col="time", data=df_tips);

# %%
sns.relplot(x="timepoint", y="signal", hue="subject",
            col="region", row="event", height=3,
            kind="line", estimator=None, data=df_fmri);

# %%
sns.relplot(x="timepoint", y="signal", 
            hue="event", style="event",
            col="subject", col_wrap=5, height=3, 
            aspect=.80, linewidth=2.5, kind="line", 
            data=df_fmri.query("region == 'frontal'"));

# %% [markdown]
# ## Histograma

# %% [markdown]
# * https://seaborn.pydata.org/tutorial/distributions.html

# %%
sns.displot(df_penguins, x="flipper_length_mm");

# %% [markdown]
# #### Quantidade de barras - bins

# %%
sns.displot(df_penguins, x="flipper_length_mm", bins=3);

# %%
sns.displot(df_penguins, x="flipper_length_mm", bins=13);

# %%
sns.displot(df_penguins, x="flipper_length_mm", bins=30);

# %%
sns.displot(df_penguins, x="flipper_length_mm", bins=100);

# %% [markdown]
# #### Quebras de bins

# %%
sns.displot(df_penguins, x="flipper_length_mm", bins=[0,100,150,170,190,200,250,300]);

# %% [markdown]
# #### Quebra discreta

# %%
sns.displot(df_penguins, x="flipper_length_mm", discrete=True);

# %% [markdown]
# #### Largura da barra

# %%
sns.displot(df_tips, x="day", shrink=1);

# %%
sns.displot(df_tips, x="day", shrink=5);

# %%
sns.displot(df_tips, x="day", shrink=0.3);

# %% [markdown]
# ### Comparação

# %% [markdown]
# #### Hue

# %%
sns.displot(df_penguins, x="flipper_length_mm", hue="species");

# %% [markdown]
# #### Element

# %%
sns.displot(df_penguins, x="flipper_length_mm", hue="species", element="step");

# %% [markdown]
# #### Multiple

# %%
sns.displot(df_penguins, x="flipper_length_mm", hue="species", multiple="stack");

# %%
sns.displot(df_penguins, x="flipper_length_mm", hue="species", multiple="dodge");

# %% [markdown]
# ### Multiplos

# %%
sns.displot(df_penguins, x="flipper_length_mm", col="sex");

# %% [markdown]
# ### Densidade

# %%
sns.displot(df_penguins, x="flipper_length_mm", kind="kde");

# %%
sns.displot(df_penguins, x="flipper_length_mm", kind="kde", bw_adjust=.25);

# %% [markdown]
# ### Distribuição cumulativa

# %%
sns.displot(df_penguins, x="flipper_length_mm", kind="ecdf");

# %% [markdown]
# ### Distribuição bivariadas

# %%
sns.displot(df_penguins, x="bill_length_mm", y="bill_depth_mm", cbar=True);

# %%
sns.displot(df_penguins, x="bill_length_mm", y="bill_depth_mm", kind="kde");

# %% [markdown]
# ### Distribuição conjunta

# %%
sns.jointplot(data=df_penguins, x="bill_length_mm", y="bill_depth_mm");

# %%
g = sns.JointGrid(data=df_penguins, x="bill_length_mm", y="bill_depth_mm")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)

# %% [markdown]
# ### Distribuição em pares

# %%
sns.pairplot(df_penguins);

# %% [markdown]
# ## Gráfico Categórico

# %%
sns.catplot(x="day", y="total_bill", data=df_tips);

# %% [markdown]
# #### jitter

# %%
sns.catplot(x="day", y="total_bill", jitter=False, data=df_tips);

# %% [markdown]
# #### Kind

# %%
sns.catplot(x="day", y="total_bill", kind="swarm", data=df_tips);

# %% [markdown]
# #### Hue

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=df_tips);

# %% [markdown]
# ## Boxplot

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=df_tips);

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=df_tips);

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="violin", data=df_tips);

# %% [markdown]
# ## Gráfico de Barras

# %%
sns.catplot(x="survived", y="sex", kind="bar", data=df_titanic);

# %%
sns.catplot(x="sex", y="survived", kind="bar", data=df_titanic);

# %%
sns.catplot(x="sex", kind="count", data=df_titanic);

# %% [markdown]
# #### Ci

# %%
sns.catplot(x="sex", y="survived", kind="bar", data=df_titanic, ci=False);

# %% [markdown]
# #### Hue

# %%
sns.catplot(x="sex", y="survived", kind="bar", hue='class', data=df_titanic);

# %% [markdown]
# #### palette

# %%
sns.catplot(x="sex", y="survived", kind="bar", hue='class', palette="ch:.25", data=df_titanic);

# %% [markdown]
# ## Heatmap

# %%
sns.heatmap(corr_crash, cmap='Blues');

# %% [markdown]
# #### annot

# %%
sns.heatmap(corr_crash, annot=True, cmap='Blues');

# %% [markdown]
# #### Separação

# %%
sns.heatmap(corr_crash, cmap='Blues', linecolor='white', linewidths=1);

# %%
sns.heatmap(corr_crash, annot=True, cmap='Blues', linecolor='white', linewidths=1);

# %% [markdown]
# ## Gráfico agrupamento

# %%
df_cluster = df_tips[['total_bill','tip','size']].copy()
df_cluster.index = df_tips['day']
df_cluster.head(4)
# Out:
#      total_bill   tip  size
# day
# Sun       16.99  1.01     2
# Sun       10.34  1.66     3
# Sun       21.01  3.50     3
# Sun       23.68  3.31     2

# %%
sns.clustermap(df_cluster);

# %%
sns.boxenplot(x = "day", y = "total_bill",  
              data = df_tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
